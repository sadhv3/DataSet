# %% [markdown]
# <a href="https://colab.research.google.com/github/sadhv3/Project_Iris/blob/main/Project_IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Data Munging to Data Visualization

# %% [markdown]
# #### 1. Loading Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
url = "https://raw.githubusercontent.com/sadhv3/Project_Iris/main/Iris_DS.csv"
namelist = ["SepalLength" , "SepalWidth","PetalLength","PetalWidth" , "species"]
dfIris = pd.read_csv(   url , header=None , names= namelist)

# %% [markdown]
# #### 2. Data Preperation

# %%
dfIris.head(6)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth      species
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa
# 5          5.4         3.9          1.7         0.4  Iris-setosa

# %%
dfIris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   species      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
dfIris.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
# show the unique species in the dataset
dfIris.groupby('species')['species'].count()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
# slice dataframe into column
dfIris[['SepalLength', 'PetalLength']]
# dataframe['columnname']
# dataframe[['columnname1','columname2']]
# Out:
#      SepalLength  PetalLength
# 0            5.1          1.4
# 1            4.9          1.4
# 2            4.7          1.3
# 3            4.6          1.5
# 4            5.0          1.4
# ..           ...          ...
# 145          6.7          5.2
# 146          6.3          5.0
# 147          6.5          5.2
# 148          6.2          5.4
# 149          5.9          5.1
#
# [150 rows x 2 columns]

# %%
# slice dataframe into rows
# use dataframe.loc/iloc
# dfIris[49:55]
dfIris.iloc[49:55]
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth          species
# 49          5.0         3.3          1.4         0.2      Iris-setosa
# 50          7.0         3.2          4.7         1.4  Iris-versicolor
# 51          6.4         3.2          4.5         1.5  Iris-versicolor
# 52          6.9         3.1          4.9         1.5  Iris-versicolor
# 53          5.5         2.3          4.0         1.3  Iris-versicolor
# 54          6.5         2.8          4.6         1.5  Iris-versicolor

# %%
# slice dataframe into rows
# use dataframe.loc/iloc
#  show only sepallenght and sepal width
# dfIris.iloc[49:55, :2]
# dfIris.loc[49:55, ['SepalLength','SepalWidth']]
dfIris.iloc[49:55, :2]
# Out:
#     SepalLength  SepalWidth
# 49          5.0         3.3
# 50          7.0         3.2
# 51          6.4         3.2
# 52          6.9         3.1
# 53          5.5         2.3
# 54          6.5         2.8

# %%
# average sepal lenght
dfIris['SepalLength'].mean()
# Out:
# 5.843333333333334

# %%
# show the records having sepallenth more than mean value
m=dfIris['SepalLength'].mean()
dfIris.loc[dfIris['SepalLength'] >m] [ 'SepalLength']
# Out:
# 50     7.0
# 51     6.4
# 52     6.9
# 54     6.5
# 56     6.3
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLength, Length: 70, dtype: float64

# %%
# show the records having sepallenth more than mean value
# m=dfIris['SepalLength'].mean()
dfIris.loc[dfIris['SepalLength'] >dfIris['SepalLength'].mean()] [ 'SepalLength']
# Out:
# 50     7.0
# 51     6.4
# 52     6.9
# 54     6.5
# 56     6.3
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLength, Length: 70, dtype: float64

# %% [markdown]
# #### Plot Graph

# %%
# draw historam x - species y- sepal Length
dfIris [['SepalLength', 'species']]
# Out:
#      SepalLength         species
# 0            5.1     Iris-setosa
# 1            4.9     Iris-setosa
# 2            4.7     Iris-setosa
# 3            4.6     Iris-setosa
# 4            5.0     Iris-setosa
# ..           ...             ...
# 145          6.7  Iris-virginica
# 146          6.3  Iris-virginica
# 147          6.5  Iris-virginica
# 148          6.2  Iris-virginica
# 149          5.9  Iris-virginica
#
# [150 rows x 2 columns]

# %%
# x = dfIris[dfIris['species']=='Iris-virginica']['species']
# y= dfIris[dfIris['species']=='Iris-virginica']['SepalLength']
# plt.plot(x,y)
plt.plot( dfIris['SepalLength'] , dfIris['SepalWidth'])
# plt.scatter(dfIris['SepalLength'] , dfIris['SepalWidth'] )

# %%
# plot the graph  with dfIris ["PetalLength"] on x axis and
# dfIris["SepalLength"] on y axis

plt.scatter( dfIris ["PetalLength"], dfIris["SepalLength"] )
#default is line graph -

# %%
plt.plot   (   dfIris["PetalLength"] ,"go" )

# %%
# scatter plot
dfIris.plot( kind = "scatter" ,x="SepalLength" , y="PetalLength")
plt.grid()

# %% [markdown]
# ## Plotting with Seaborn

# %%
import seaborn as sns

iris = sns.load_dataset('iris')

# style used as a theme of graph for example if we want black
# graph with grid then write "darkgrid"
sns.set_style("whitegrid")

# sepal_length, petal_length are iris  feature data height used to define
# Height of graph whereas hue store the class of iris dataset.
sns.FacetGrid(iris, hue ="species",height = 6).map(plt.scatter,'sepal_length', 'petal_length').add_legend()

# %%
sns.pairplot(iris, hue="species", palette="husl", size=3)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import pandas as pd
url ="https://raw.githubusercontent.com/sadhv3/Project_Iris/main/Iris_DS.csv"
nameslist = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
dfIris =  pd.read_csv(url, header=None, names=nameslist)
dfIris
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Describe data

# %%
dfIris.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
dfIris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   Species      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# #### Visualize data

# %%
dfIris.groupby('Species').size()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
dfIris['SepalLength'].hist()
# Out:
# <Axes: >

# %%
# scatter chart
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
scatter_matrix(dfIris)
plt.show()

# %%
# scatter matrix with seaborn
import seaborn as sns
sns.set_theme(style="ticks")
sns.pairplot(dfIris,hue = 'Species')

# %%
dfIris.hist()
plt.show()

# %%
dfIris.plot()
plt.show()

# %%
dfIris.plot(kind='box')
plt.show()

# %%
dfIris.plot(kind='box' , subplots=True, layout=(2,2))
plt.show()

# %% [markdown]
# #### model building ( Classification )

# %%
df2 = dfIris.values
print(df2.shape)
# Out:
# (150, 5)

# %%
df2[:10,:4]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3.0, 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5.0, 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5.0, 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1]], dtype=object)

# %%
#divide data into feature matrix and target matrix
X = df2[:,:4] # all the rows and first four columns 0-3
Y = df2[:,4]   # all the rows and only fourth column (last column )
print(X.shape, Y.shape)
# Out:
# (150, 4) (150,)

# %%
# fit this in model
from sklearn.linear_model import LogisticRegression
model1= LogisticRegression()

# %%
model1.fit(X,Y)
# Out:
# LogisticRegression()

# %%
model1.predict([[  5.1,3.5,1.4,0.2 ]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
model1.predict ([[2.9,3.0,3.1,1.8]])
# Out:
# array(['Iris-setosa'], dtype=object)
